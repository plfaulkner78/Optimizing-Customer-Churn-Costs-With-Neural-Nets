# %% [markdown]
# ## Cost Sensitive Customer Churn Prediction
# Churn prediction is a business problem where a company wants to predict whether a customer under some kind of renewable contract, such as a mobile cell phone plan, will stay with the company or leave (churn). Companies want to know whether or not a customer is likely to churn to help the company decide what, if any, action it should take with the customer. However, this is more than a regular machine learning classification problem; this is a business problem, with marketing costs and customer lifetime value involved. Therefore, the goal of this model is not to maximize F1 Score or minimize cross entropy loss explicitly, but rather to ***minimize overall costs***. Although it involves classification, at heart this is really a cost optimization problem.

# %%
import pandas as pd

data = pd.read_csv('iranian_churn.csv')

# %%
print(data.shape)
data.head()
# Out:
# (3150, 16)
#    Call  Failure  Complains  Subscription  Length  Charge  Amount  \
# 0              8          0                    38               0
# 1              0          0                    39               0
# 2             10          0                    37               0
# 3             10          0                    38               0
# 4              3          0                    38               0
#
#    Seconds of Use  Frequency of use  Frequency of SMS  \
# 0            4370                71                 5
# 1             318                 5                 7
# 2            2453                60               359
# 3            4198                66                 1
# 4            2393                58                 2
#
#    Distinct Called Numbers  Age Group  Tariff Plan  Status  Age  \
# 0                       17          3            1       1   30
# 1                        4          2            1       2   25
# 2                       24          3            1       1   30
# 3                       35          1            1       1   15
# 4                       33          1            1       1   15
#
#    Customer Value         FN        FP  Churn
# 0         197.640   177.8760   69.7640      0
# 1          46.035    41.4315   60.0000      0
# 2        1536.520  1382.8680  203.6520      0
# 3         240.020   216.0180   74.0020      0
# 4         145.805   131.2245   64.5805      0

# %% [markdown]
# The dataset contains a number of potential predictor variables as well as the costs of False Positives and False Negatives for each instance. This is what will allow me to perform cost-sensitive learning. The target class is the binary variable "Churn".

# %% [markdown]
# ### Exploratory data analysis

# %%
data['Churn'].value_counts()
# Out:
# 0    2655
# 1     495
# Name: Churn, dtype: int64

# %% [markdown]
# This dataset has a class imbalance, with many more instances of customers not churning than churning. I will be sure to use stratified sampling when I split my data into train, validation, and test sets to maintain a representation of this balance.

# %%
data.describe()
# Out:
#        Call  Failure    Complains  Subscription  Length  Charge  Amount  \
# count    3150.000000  3150.000000           3150.000000     3150.000000
# mean        7.627937     0.076508             32.541905        0.942857
# std         7.263886     0.265851              8.573482        1.521072
# min         0.000000     0.000000              3.000000        0.000000
# 25%         1.000000     0.000000             30.000000        0.000000
# 50%         6.000000     0.000000             35.000000        0.000000
# 75%        12.000000     0.000000             38.000000        1.000000
# max        36.000000     1.000000             47.000000       10.000000
#
#        Seconds of Use  Frequency of use  Frequency of SMS  \
# count     3150.000000       3150.000000       3150.000000
# mean      4472.459683         69.460635         73.174921
# std       4197.908687         57.413308        112.237560
# min          0.000000          0.000000          0.000000
# 25%       1391.250000         27.000000          6.000000
# 50%       2990.000000         54.000000         21.000000
# 75%       6478.250000         95.000000         87.000000
# max      17090.000000        255.000000        522.000000
#
#        Distinct Called Numbers    Age Group  Tariff Plan       Status  \
# count              3150.000000  3150.000000  3150.000000  3150.000000
# mean                 23.509841     2.826032     1.077778     1.248254
# std                  17.217337     0.892555     0.267864     0.432069
# min                   0.000000     1.000000     1.000000     1.000000
# 25%                  10.000000     2.000000     1.000000     1.000000
# 50%                  21.000000     3.000000     1.000000     1.000000
# 75%                  34.000000     3.000000     1.000000     1.000000
# max                  97.000000     5.000000     2.000000     2.000000
#
#                Age  Customer Value           FN           FP        Churn
# count  3150.000000     3150.000000  3150.000000  3150.000000  3150.000000
# mean     30.998413      470.972916   423.875624    98.304688     0.157143
# std       8.831095      517.015433   465.313890    50.724492     0.363993
# min      15.000000        0.000000     0.000000    60.000000     0.000000
# 25%      25.000000      113.801250   102.421125    61.380125     0.000000
# 50%      30.000000      228.480000   205.632000    72.848000     0.000000
# 75%      30.000000      788.388750   709.549875   128.838875     0.000000
# max      55.000000     2165.280000  1948.752000   266.528000     1.000000

# %%
# Visualize the correlations among features
import seaborn as sns

sns.heatmap(data.corr(), cmap='coolwarm')

# %%
# Shows which features are most correlated with Churn
data.corr()['Churn'].sort_values(ascending=False)
# Out:
# Churn                      1.000000
# Complains                  0.532053
# Status                     0.498976
# Call  Failure             -0.008987
# Age Group                 -0.014550
# Age                       -0.017705
# Subscription  Length      -0.032588
# Tariff Plan               -0.105853
# Charge  Amount            -0.202305
# Frequency of SMS          -0.220754
# FP                        -0.278057
# Distinct Called Numbers   -0.278867
# Customer Value            -0.289144
# FN                        -0.289144
# Seconds of Use            -0.298935
# Frequency of use          -0.303337
# Name: Churn, dtype: float64

# %% [markdown]
# "Complains" and "Status" are the features most positively correlated with Churn.

# %% [markdown]
# --------------------------
#
# ## Data Preparation
#
# The repository where I found this dataset had a description for some of the columns but not for all of them. Therefore, I must get more info about these features and see if there are any categorical variables that need to be encoded as numbers.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Call  Failure            3150 non-null   int64
#  1   Complains                3150 non-null   int64
#  2   Subscription  Length     3150 non-null   int64
#  3   Charge  Amount           3150 non-null   int64
#  4   Seconds of Use           3150 non-null   int64
#  5   Frequency of use         3150 non-null   int64
#  6   Frequency of SMS         3150 non-null   int64
#  7   Distinct Called Numbers  3150 non-null   int64
#  8   Age Group                3150 non-null   int64
#  9   Tariff Plan              3150 non-null   int64
#  10  Status                   3150 non-null   int64
#  11  Age                      3150 non-null   int64
#  12  Customer Value           3150 non-null   float64
#  13  FN                       3150 non-null   float64
#  14  FP                       3150 non-null   float64
#  15  Churn                    3150 non-null   int64
# dtypes: float64(3), int64(13)
# memory usage: 393.9 KB

# %%
# Print out the number of unique values for each feature 
for feature in data.columns.tolist():
    print(feature)
    print(data[feature].nunique())
    print('\n')
# Out:
# Call  Failure
# 37
#
#
# Complains
# 2
#
#
# Subscription  Length
# 45
#
#
# Charge  Amount
# 11
#
#
# Seconds of Use
# 1756
#
#
# Frequency of use
# 242
#
#
# Frequency of SMS
# 405
#
#
# Distinct Called Numbers
# 92
#
#
# Age Group
# 5
#
#
# Tariff Plan
# 2
#
#
# Status
# 2
#
#
# Age
# 5
#
#
# Customer Value
# 2654
#
#
# FN
# 2654
#
#
# FP
# 2195
#
#
# Churn
# 2

# %% [markdown]
# Now I will inspect the featues that had a small number of unique values, as these features are likely categorical variables.

# %%
# Complains appears to be a binary variable ==> no further encoding is needed
data['Complains'].value_counts()
# Out:
# 0    2909
# 1     241
# Name: Complains, dtype: int64

# %%
# Check 'Charge Amount' because it has relatively few unique values
data['Charge  Amount'].value_counts()
# Out:
# 0     1768
# 1      617
# 2      395
# 3      199
# 4       76
# 5       30
# 8       19
# 9       14
# 7       14
# 6       11
# 10       7
# Name: Charge  Amount, dtype: int64

# %% [markdown]
# 'Charge Amount' is indeed a categorical variable, but it has a natural ordinal encoding so it doesn't need any further encoding.

# %%
# Age Group
data['Age Group'].value_counts()
# Out:
# 3    1425
# 2    1037
# 4     395
# 5     170
# 1     123
# Name: Age Group, dtype: int64

# %% [markdown]
# 'Age Group' is a categorical variable as well, but according to the description of the dataset's columns, these categories have an ordinal pattern so no further encoding is needed.

# %%
# Tariff Plan
data['Tariff Plan'].value_counts()
# Out:
# 1    2905
# 2     245
# Name: Tariff Plan, dtype: int64

# %% [markdown]
# 'Tariff Plan' is also a categorical variable, but it does not have an ordinal encoding and is not currently formatted as a binary variable. There are only two categories, but they are not encoded as 0 and 1. I will encode this feature below by changing category 1 to 0 and category 2 to 1.

# %%
data['Tariff Plan'] = data['Tariff Plan'].apply(lambda x: x - 1 )

# %%
data['Tariff Plan'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Tariff Plan, dtype: int64

# %%
# Status
data['Status'].value_counts()
# Out:
# 1    2368
# 2     782
# Name: Status, dtype: int64

# %%
# Status also needs to be re-encoded to 0s and 1s
data['Status'] = data['Status'].apply(lambda x: x - 1 )

# %%
data['Status'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Status, dtype: int64

# %%
# Age
data['Age'].value_counts()
# Out:
# 30    1425
# 25    1037
# 45     395
# 55     170
# 15     123
# Name: Age, dtype: int64

# %% [markdown]
# 'Age' is already represented in 'Age Group', so I will drop this redundant feature.

# %%
data.drop('Age', axis=1, inplace=True)

# %%
data.shape
# Out:
# (3150, 15)

# %%
data.head()
# Out:
#    Call  Failure  Complains  Subscription  Length  Charge  Amount  \
# 0              8          0                    38               0
# 1              0          0                    39               0
# 2             10          0                    37               0
# 3             10          0                    38               0
# 4              3          0                    38               0
#
#    Seconds of Use  Frequency of use  Frequency of SMS  \
# 0            4370                71                 5
# 1             318                 5                 7
# 2            2453                60               359
# 3            4198                66                 1
# 4            2393                58                 2
#
#    Distinct Called Numbers  Age Group  Tariff Plan  Status  Customer Value  \
# 0                       17          3            0       0         197.640
# 1                        4          2            0       1          46.035
# 2                       24          3            0       0        1536.520
# 3                       35          1            0       0         240.020
# 4                       33          1            0       0         145.805
#
#           FN        FP  Churn
# 0   177.8760   69.7640      0
# 1    41.4315   60.0000      0
# 2  1382.8680  203.6520      0
# 3   216.0180   74.0020      0
# 4   131.2245   64.5805      0

# %% [markdown]
# ### Split the data into train, validation, and test sets

# %%
# Drop the labels from the input data and select 'Churn' for the labels

X = data.drop(['Churn'], axis=1)
y = data['Churn']

# %%
print(X.shape)
print(y.shape)
# Out:
# (3150, 14)
# (3150,)

# %%
from sklearn.model_selection import train_test_split

# Set the 'stratify' parameter so the class balance is preserved
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.15, stratify=y, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, 
                                                      test_size=0.15, stratify=y_train_full, random_state=42)

# %%
print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
print(y_train.shape)
print(y_valid.shape)
print(y_test.shape)
# Out:
# (2275, 14)
# (402, 14)
# (473, 14)
# (2275,)
# (402,)
# (473,)

# %% [markdown]
# Below I will select and remove the FN and FP columns from each of the datasets so they can be used to calculate misclassification costs later and will not be predictors directly.

# %%
train_misclassification_costs_df = X_train[['FN', 'FP']]
valid_misclassification_cost_df = X_valid[['FN', 'FP']]
test_misclassification_cost_df = X_test[['FN', 'FP']]

# Drop the columns from each dataset
X_train.drop(['FN', 'FP'], axis=1, inplace=True)
X_valid.drop(['FN', 'FP'], axis=1, inplace=True)
X_test.drop(['FN', 'FP'], axis=1, inplace=True)
# Out:
# /Users/PayPay/ml/my_env/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
# Out:
# (2275, 12)
# (402, 12)
# (473, 12)

# %%
print(y_train.value_counts() / len(y_train))
print(y_valid.value_counts() / len(y_valid))
print(y_test.value_counts() / len(y_test))
# Out:
# 0    0.842637
# 1    0.157363
# Name: Churn, dtype: float64
# 0    0.843284
# 1    0.156716
# Name: Churn, dtype: float64
# 0    0.843552
# 1    0.156448
# Name: Churn, dtype: float64

# %% [markdown]
# The data has been split into train, validation, and test sets, and the class balance of churn vs. no churn has been maintained across these datasets.

# %% [markdown]
# ### Scale the input features.

# %%
import matplotlib.pyplot as plt

X_train.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# Because the input variables are not normally distributed, I will use MinMaxScaler to normalize the data rather than StandardScaler.

# %%
# Scale the input features
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train) # fit the scaler on the training set and transform it

# Transform, but do not fit, the validation and test sets
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# -------

# %% [markdown]
# ## Build the Model

# %% [markdown]
# ### First a note on the cost-sensitive learning approach and the evaluation metric.
# This dataset includes the economic cost in dollars of misclassifying instances. This allows me to perform cost-sensitive learning. The dataset doesn't make it clear how these costs are calculated, but in a real business scenario, I would hopefully have access to more context or people who could explain these costs. Regardless of their provenance, I will use these costs in my model. There are two approaches I can take to incorporate these misclassification costs:
#
# 1) I can create a custom loss function that incorporates the cost of false positives and false negatives directly. So during training, the binary crossentropy loss function being optimized will know not to punish false positives and false negatives equally, but rather according to their actual costs. When the model spits out a prediction, it will have already considered to costs of false negatives and false positives.
#
# 2) I can leave the loss function alone and have the model predict class probabilities. Then I can create a custom function that uses these probabilities and the costs of false positives and false negatives to calculate an expected cost value for predicting Churn and an expected cost value for predicting No Churn. Then this function can simply select the prediction with the lowest expected cost to be the model's final prediction.
#
# These adjustments above mean that traditional classification evaluation metrics such as the F1 score will not suffice as the most relevant measure of performance. Instead, the model needs an evaluation metric that will incorporate the costs of False Positives and False Negatives. Therefore, I will create a custom metric that captures ***Cost Savings***.
#
# To calculate this metric, I will first calculate a baseline cost by determining what the cost would be if the company randomly guessed which customers would churn. Then I will use the trained model to make predictions and calculate the misclassification costs of these predictions. Finally, I will be able to compare the model's cost to the random guessing scenario's cost and determine the cost savings. So I want the *Cost Savings* (baseline cost - model's cost) to be as high as possible.
#
# One final note, the dataset includes costs for false positives and false negatives but not for true positives and true negatives. Realistically, in a churn problem like this a true positive likely would not have a cost of $ 0 because usually the company would send this likely-churning customer some marketing materials or conduct some kind of outreach. For now though, I will keep the true positive cost at 0 dollars, but I will create a variable to represent the cost of a true positive so it can be changed easily if needed.
#
# Now, on to model building!

# %% [markdown]
# ### I will build the second model described above, using the expected cost as a decision heuristic at the end of the model rather than creating a custom loss function. Below are the functions needed to build this second model as well as the custom evaluation metric.

# %%
import numpy as np

# %%
# True positive and true negative cost variables
tp_cost = 0
tn_cost = 0

# %%
# This is the final prediction layer that uses the expected value of costs to make its final predictions
def expected_value_prediction(model, input_data, misclassification_df):
    """
    This function takes a trained model and
    input_data to make predictions on as well as a
    misclassification costs dataframe.
    The model will predict class probabilities
    and the function will compute expected values using
    these probabilities and the misclassification cost data.
    This function will return a numpy array of class predictions.
    """
    y_probas = model.predict(input_data) # get the predicted probability of Churn for each instance
    class_predictions = []
    
    # Iterate through all the predicted probabilities, calculate expected values and classify each instance as
    # either 0 or 1 depending on which expected cost value was lower. Append each prediction to the list.
    for index, churn_proba in enumerate(y_probas.reshape(input_data.shape[0])): # reshape y_probas as a 1D array
        # expected_cost_churn is the expected cost of predicting churn
        expected_cost_churn = (tp_cost * churn_proba) + (misclassification_df['FP'].iloc[index] * (1 - churn_proba))
        # expected_cost_no_churn is the expected cost of predicting no churn
        expected_cost_no_churn = (tn_cost * (1 - churn_proba)) + (misclassification_df['FN'].iloc[index] * churn_proba)

        if expected_cost_churn < expected_cost_no_churn:
            prediction = 1
        else:
            prediction = 0
            
        class_predictions.append(prediction)
        
    return np.array(class_predictions)

# %%
def prediction_term(actual, predicted):
    """
    Function takes the actual and predicted class value
    of an instance and returns a string signifying
    whether the instance is a true positive, true negative
    false positive or false negative.
    """
    tup = (actual, predicted)
    if tup == (0, 0):
        return 'TN'
    elif tup == (0, 1):
        return 'FP'
    elif tup == (1, 0):
        return 'FN'
    elif tup == (1, 1):
        return 'TP'

# %%
def calculate_cost(true_labels, predictions, misclassification_df):
    """
    Function takes true labels, predictions, and the
    misclassification dataframe containing the
    false negative and false positive costs as input.
    Then it classifies predictions as either
    TP, TN, FP, FN and sums up the respective costs.
    Returns a the total cost of these predictions
    as a float.
    """
    total_cost = 0
    for index, value in enumerate(predictions):
        term = prediction_term(true_labels[index], value)
        if term == 'FN' or term == 'FP':
            total_cost += misclassification_df[term].iloc[index]
        elif term == 'TP':
            total_cost += tp_cost
        elif term == 'TN':
            total_cost += tn_cost
    return total_cost

# %%
# Below is the custom evaluation function
def evaluate_cost_savings(model, misclassification_costs_df, input_data, true_labels):
    """
    This function calculates the Cost Savings metric.
    It takes a trained model, a misclassification costs dataframe,
    input data, and the true class labels as input.
    Then it calculates the baseline cost under the random guessing
    scenario and the cost obtained by the cost sensitive trained model.
    Returns the difference between baseline cost and model's cost
    as a number in dollars. Larger values indicate a better model.
    """
    # Convert the Labels pandas Series to a list
    true_labels = true_labels.to_numpy()
    
    # Calculate the baseline cost of random guessing
    
    # Randomly generate an array of 0s and 1s with a length the size of the labels, then calculate the cost
    np.random.seed(42)
    random_guess_classes = np.random.randint(2, size=len(true_labels))
    random_cost = calculate_cost(true_labels, random_guess_classes, misclassification_costs_df)
    
    # Calculate the trained cost sensitive model's cost
    
    # Get the predicted class based on the expected cost values
    y_prediction_classes = expected_value_prediction(model, input_data, misclassification_costs_df)
    model_cost = calculate_cost(true_labels, y_prediction_classes, misclassification_costs_df)
    
    # Calculate cost savings
    cost_savings = random_cost - model_cost
    
    print("Random Guess Baseline Cost: $" + str(round(random_cost, 2)))
    print("Model Cost: $" + str(round(model_cost, 2)))
    print("Cost Savings: $" + str(round(cost_savings, 2)))
    print('\n')
    return cost_savings

# %% [markdown]
# ### Automatically test for the ideal hyperparameters
#
# #### I had planned on using GridSearch to automatically search for the best set of hyperparameters. However, this required me to create a function that returned a Keras model, wrap this model in a Scikit Learn wrapper, and create a custom scorer based on my Cost Savings evaluation metric, all to put my model in a format that the standard GridSearch could use. Instead of changing my current setup to fit GridSearch's setup, why not just create a custom GridSearch that already fits my current setup? This is done below.

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers
K = keras.backend

# %% [markdown]
# First make a function that creates a model given some hyperparameters.

# %%
def create_model(weight_initialization, activation, dropout_rate):
    """
    Function takes hyperparameter arguments and creates a
    Keras model using these hyperparameters.
    Returns a model ready for compilation and training.
    """
    model = keras.models.Sequential([
        layers.Dense(48, input_dim=X_train_scaled.shape[1], kernel_initializer=weight_initialization, 
                     activation=activation),
        layers.Dropout(dropout_rate),
        layers.Dense(36, kernel_initializer=weight_initialization, activation=activation),
        layers.Dropout(dropout_rate),
        layers.Dense(28, kernel_initializer=weight_initialization, activation=activation),
        layers.Dropout(dropout_rate),
        layers.Dense(20, kernel_initializer=weight_initialization, activation=activation),
        layers.Dropout(dropout_rate),
        layers.Dense(14, kernel_initializer=weight_initialization, activation=activation),
        layers.Dropout(dropout_rate),
        layers.Dense(8, kernel_initializer=weight_initialization, activation=activation),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

# %% [markdown]
# Next define a set of hyperparameters to test in the grid search.

# %%
# I will give each layer the same initialization rather than vary the initializations across the layers
weight_initializations = ['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 
                         'he_normal', 'he_uniform']

# These activations will only apply to the hidden layers; the output's activation must be sigmoid for this problem
activation_functions = ['relu', 'selu', 'elu']

# Dropout rates
dropout_rates = [0.2, 0.5, 0.8]

# %% [markdown]
# I could also search for the ideal number of neurons and layers, but I will keep those constant and only adjust the variables above. The combination of these parameters results in 72 different models that will be built, trained, and tested.

# %% [markdown]
# Next, create a custom grid search function.

# %%
def run_grid_search(weight_initializations, activation_functions, dropout_rates):
    """
    Function takes lists of hyperparameters to test,
    builds many models with an exhaustive combination
    of the hyperparameters, evaluates the models using
    the cost savings metric, and stores the model parameter
    configurations and scores in a list that it returns.
    """
    
    # Keep a list of dicts containing model parameters and their scores. This list will be sorted by cost_savings 
    # score to determine the best performing configuration.
    model_scores_params = []
    
    for weight in weight_initializations:
        for activation in activation_functions:
            for rate in dropout_rates:
                model = create_model(weight, activation, rate)
                model.compile(loss='binary_crossentropy', optimizer='adam')
                model.fit(X_train_scaled, y_train, epochs=100, validation_data=(X_valid_scaled, y_valid), verbose=0)
                
                # Evaluate the cost savings metric on the validation data
                cost_savings = evaluate_cost_savings(model, valid_misclassification_cost_df, X_valid_scaled, y_valid)
                # Store the results from this iteration
                model_scores_params.append({'weight_initialization': weight, 'activation': activation,
                                            'dropout_rate': rate, 'cost_savings': cost_savings})   
    
    return model_scores_params

# %% [markdown]
# #### Finally, run the grid search!

# %%
# Clear backend and set random seed
K.clear_session()

from tensorflow.random import set_seed
set_seed(42)

# %%
# I want to see how long the grid search takes, so I will keep track of the time elapsed
import time

# %%
start = time.time()
grid_search_results = run_grid_search(weight_initializations, activation_functions, dropout_rates)
end = time.time()
# Out:
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1313.61
# Cost Savings: $17724.36
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2075.71
# Cost Savings: $16962.25
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $4436.28
# Cost Savings: $14601.69
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2648.32
# Cost Savings: $16389.65
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2904.99
# Cost Savings: $16132.98
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2907.24
# Cost Savings: $16130.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3186.42
# Cost Savings: $15851.55
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3024.99
# Cost Savings: $16012.98
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3177.75
# Cost Savings: $15860.22
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1168.08
# Cost Savings: $17869.89
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1883.17
# Cost Savings: $17154.8
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $4131.19
# Cost Savings: $14906.78
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3253.21
# Cost Savings: $15784.76
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3117.93
# Cost Savings: $15920.04
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23023.3
# Cost Savings: $-3985.33
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3263.59
# Cost Savings: $15774.38
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2803.39
# Cost Savings: $16234.58
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $4059.49
# Cost Savings: $14978.48
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1394.6
# Cost Savings: $17643.36
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1923.75
# Cost Savings: $17114.21
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $4169.92
# Cost Savings: $14868.05
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2408.61
# Cost Savings: $16629.36
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2865.44
# Cost Savings: $16172.52
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2898.54
# Cost Savings: $16139.43
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3285.09
# Cost Savings: $15752.88
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3024.99
# Cost Savings: $16012.98
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2964.52
# Cost Savings: $16073.44
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23147.7
# Cost Savings: $-4109.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23147.7
# Cost Savings: $-4109.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23147.7
# Cost Savings: $-4109.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23147.7
# Cost Savings: $-4109.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23147.7
# Cost Savings: $-4109.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23147.7
# Cost Savings: $-4109.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23147.7
# Cost Savings: $-4109.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23147.7
# Cost Savings: $-4109.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23147.7
# Cost Savings: $-4109.73
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1325.8
# Cost Savings: $17712.17
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2300.21
# Cost Savings: $16737.76
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $4006.91
# Cost Savings: $15031.05
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2846.2
# Cost Savings: $16191.77
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3079.73
# Cost Savings: $15958.24
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $22254.24
# Cost Savings: $-3216.28
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3047.76
# Cost Savings: $15990.21
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2898.54
# Cost Savings: $16139.43
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $4049.95
# Cost Savings: $14988.02
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1486.5
# Cost Savings: $17551.47
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1937.93
# Cost Savings: $17100.04
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3965.04
# Cost Savings: $15072.93
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2515.1
# Cost Savings: $16522.87
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3000.75
# Cost Savings: $16037.22
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23392.25
# Cost Savings: $-4354.28
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1884.12
# Cost Savings: $17153.85
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2913.26
# Cost Savings: $16124.71
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $4082.04
# Cost Savings: $14955.93
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $1533.79
# Cost Savings: $17504.18
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3453.62
# Cost Savings: $15584.35
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $25200.99
# Cost Savings: $-6163.02
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3270.02
# Cost Savings: $15767.95
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3185.97
# Cost Savings: $15852.0
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23629.85
# Cost Savings: $-4591.88
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2824.71
# Cost Savings: $16213.26
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2913.98
# Cost Savings: $16123.99
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23629.85
# Cost Savings: $-4591.88
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2001.25
# Cost Savings: $17036.72
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3074.96
# Cost Savings: $15963.01
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $25273.31
# Cost Savings: $-6235.34
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3025.14
# Cost Savings: $16012.82
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3451.34
# Cost Savings: $15586.63
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $19007.05
# Cost Savings: $30.91
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $2842.97
# Cost Savings: $16195.0
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $3079.76
# Cost Savings: $15958.21
#
#
# Random Guess Baseline Cost: $19037.97
# Model Cost: $23143.73
# Cost Savings: $-4105.76
#
#
#
#
# 3070.028568983078

# %%
print((end - start) / 60, 'minutes')
# Out:
# 51.16714281638463 minutes

# %%
sorted_results = sorted(grid_search_results, key=lambda k: k['cost_savings'], reverse=True)
best_model = sorted_results[0]
best_model
# Out:
# {'weight_initialization': 'lecun_uniform',
#  'activation': 'relu',
#  'dropout_rate': 0.2,
#  'cost_savings': 17869.887500000004}

# %% [markdown]
# The grid search found the above hyperparameters to be the ones that maximized cost savings.

# %% [markdown]
# ### I will now create a fresh model with these optimal hyperparameters and train the model for a greater number of epochs.

# %%
weight_initialization = best_model['weight_initialization']
activation = best_model['activation']
dropout_rate = best_model['dropout_rate']

model = keras.models.Sequential([
    layers.Dense(48, input_dim=X_train_scaled.shape[1], kernel_initializer=weight_initialization, 
                 activation=activation),
    layers.Dropout(dropout_rate),
    layers.Dense(36, kernel_initializer=weight_initialization, activation=activation),
    layers.Dropout(dropout_rate),
    layers.Dense(28, kernel_initializer=weight_initialization, activation=activation),
    layers.Dropout(dropout_rate),
    layers.Dense(20, kernel_initializer=weight_initialization, activation=activation),
    layers.Dropout(dropout_rate),
    layers.Dense(14, kernel_initializer=weight_initialization, activation=activation),
    layers.Dropout(dropout_rate),
    layers.Dense(8, kernel_initializer=weight_initialization, activation=activation),
    layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', tf.keras.metrics.AUC()])

# %%
set_seed(42)
# Fit the model
history = model.fit(X_train_scaled, y_train, epochs=500, validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/500
# 72/72 [==============================] - 1s 8ms/step - loss: 0.5280 - accuracy: 0.8215 - auc_2: 0.5226 - val_loss: 0.3489 - val_accuracy: 0.8433 - val_auc_2: 0.8762
# Epoch 2/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3212 - accuracy: 0.8426 - auc_2: 0.8531 - val_loss: 0.2693 - val_accuracy: 0.8433 - val_auc_2: 0.9050
# Epoch 3/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2859 - accuracy: 0.8426 - auc_2: 0.8809 - val_loss: 0.2607 - val_accuracy: 0.8433 - val_auc_2: 0.9117
# Epoch 4/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2765 - accuracy: 0.8426 - auc_2: 0.8816 - val_loss: 0.2534 - val_accuracy: 0.8433 - val_auc_2: 0.8998
# Epoch 5/500
# 72/72 [==============================] - 0s 4ms/step - loss: 0.2712 - accuracy: 0.8448 - auc_2: 0.8992 - val_loss: 0.2524 - val_accuracy: 0.8433 - val_auc_2: 0.9235
# Epoch 6/500
# 72/72 [==============================] - 0s 4ms/step - loss: 0.2745 - accuracy: 0.8475 - auc_2: 0.8934 - val_loss: 0.2482 - val_accuracy: 0.8607 - val_auc_2: 0.9298
# Epoch 7/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2620 - accuracy: 0.8620 - auc_2: 0.9063 - val_loss: 0.2426 - val_accuracy: 0.8955 - val_auc_2: 0.9297
# Epoch 8/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2574 - accuracy: 0.8760 - auc_2: 0.9127 - val_loss: 0.2318 - val_accuracy: 0.8980 - val_auc_2: 0.9331
# Epoch 9/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2566 - accuracy: 0.8866 - auc_2: 0.9143 - val_loss: 0.2202 - val_accuracy: 0.9005 - val_auc_2: 0.9366
# Epoch 10/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2351 - accuracy: 0.8932 - auc_2: 0.9256 - val_loss: 0.2129 - val_accuracy: 0.9005 - val_auc_2: 0.9398
# Epoch 11/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2341 - accuracy: 0.9033 - auc_2: 0.9277 - val_loss: 0.2166 - val_accuracy: 0.8955 - val_auc_2: 0.9425
# Epoch 12/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2287 - accuracy: 0.8989 - auc_2: 0.9295 - val_loss: 0.2057 - val_accuracy: 0.9080 - val_auc_2: 0.9451
# Epoch 13/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2303 - accuracy: 0.9042 - auc_2: 0.9288 - val_loss: 0.2070 - val_accuracy: 0.9005 - val_auc_2: 0.9468
# Epoch 14/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2170 - accuracy: 0.9059 - auc_2: 0.9377 - val_loss: 0.2049 - val_accuracy: 0.9080 - val_auc_2: 0.9536
# Epoch 15/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2271 - accuracy: 0.9037 - auc_2: 0.9324 - val_loss: 0.2002 - val_accuracy: 0.9080 - val_auc_2: 0.9548
# Epoch 16/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2167 - accuracy: 0.9033 - auc_2: 0.9379 - val_loss: 0.1971 - val_accuracy: 0.9080 - val_auc_2: 0.9553
# Epoch 17/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2143 - accuracy: 0.9042 - auc_2: 0.9384 - val_loss: 0.1958 - val_accuracy: 0.9080 - val_auc_2: 0.9596
# Epoch 18/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2206 - accuracy: 0.9121 - auc_2: 0.9378 - val_loss: 0.1958 - val_accuracy: 0.9080 - val_auc_2: 0.9618
# Epoch 19/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2093 - accuracy: 0.9051 - auc_2: 0.9447 - val_loss: 0.1916 - val_accuracy: 0.9080 - val_auc_2: 0.9606
# Epoch 20/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2099 - accuracy: 0.9077 - auc_2: 0.9416 - val_loss: 0.1892 - val_accuracy: 0.9080 - val_auc_2: 0.9627
# Epoch 21/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2162 - accuracy: 0.9073 - auc_2: 0.9400 - val_loss: 0.1894 - val_accuracy: 0.9104 - val_auc_2: 0.9641
# Epoch 22/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2083 - accuracy: 0.9077 - auc_2: 0.9441 - val_loss: 0.1833 - val_accuracy: 0.9179 - val_auc_2: 0.9642
# Epoch 23/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2110 - accuracy: 0.9090 - auc_2: 0.9436 - val_loss: 0.1805 - val_accuracy: 0.9229 - val_auc_2: 0.9682
# Epoch 24/500
# 72/72 [==============================] - 0s 4ms/step - loss: 0.2030 - accuracy: 0.9165 - auc_2: 0.9491 - val_loss: 0.1788 - val_accuracy: 0.9229 - val_auc_2: 0.9704
# Epoch 25/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1954 - accuracy: 0.9174 - auc_2: 0.9522 - val_loss: 0.1699 - val_accuracy: 0.9279 - val_auc_2: 0.9702
# Epoch 26/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1956 - accuracy: 0.9165 - auc_2: 0.9504 - val_loss: 0.1773 - val_accuracy: 0.9179 - val_auc_2: 0.9704
# Epoch 27/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1989 - accuracy: 0.9152 - auc_2: 0.9496 - val_loss: 0.1758 - val_accuracy: 0.9303 - val_auc_2: 0.9711
# Epoch 28/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1938 - accuracy: 0.9178 - auc_2: 0.9522 - val_loss: 0.1701 - val_accuracy: 0.9229 - val_auc_2: 0.9717
# Epoch 29/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1884 - accuracy: 0.9248 - auc_2: 0.9551 - val_loss: 0.1628 - val_accuracy: 0.9328 - val_auc_2: 0.9720
# Epoch 30/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1906 - accuracy: 0.9209 - auc_2: 0.9526 - val_loss: 0.1556 - val_accuracy: 0.9577 - val_auc_2: 0.9751
# Epoch 31/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1892 - accuracy: 0.9248 - auc_2: 0.9533 - val_loss: 0.1614 - val_accuracy: 0.9353 - val_auc_2: 0.9745
# Epoch 32/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1873 - accuracy: 0.9191 - auc_2: 0.9542 - val_loss: 0.1614 - val_accuracy: 0.9303 - val_auc_2: 0.9762
# Epoch 33/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1897 - accuracy: 0.9138 - auc_2: 0.9530 - val_loss: 0.1641 - val_accuracy: 0.9279 - val_auc_2: 0.9763
# Epoch 34/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1779 - accuracy: 0.9284 - auc_2: 0.9604 - val_loss: 0.1489 - val_accuracy: 0.9527 - val_auc_2: 0.9759
# Epoch 35/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1889 - accuracy: 0.9218 - auc_2: 0.9552 - val_loss: 0.1466 - val_accuracy: 0.9502 - val_auc_2: 0.9763
# Epoch 36/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1828 - accuracy: 0.9231 - auc_2: 0.9571 - val_loss: 0.1594 - val_accuracy: 0.9353 - val_auc_2: 0.9767
# Epoch 37/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1841 - accuracy: 0.9257 - auc_2: 0.9578 - val_loss: 0.1511 - val_accuracy: 0.9328 - val_auc_2: 0.9779
# Epoch 38/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1767 - accuracy: 0.9240 - auc_2: 0.9596 - val_loss: 0.1497 - val_accuracy: 0.9552 - val_auc_2: 0.9779
# Epoch 39/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1789 - accuracy: 0.9226 - auc_2: 0.9580 - val_loss: 0.1497 - val_accuracy: 0.9328 - val_auc_2: 0.9785
# Epoch 40/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1776 - accuracy: 0.9235 - auc_2: 0.9613 - val_loss: 0.1463 - val_accuracy: 0.9378 - val_auc_2: 0.9807
# Epoch 41/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1698 - accuracy: 0.9266 - auc_2: 0.9643 - val_loss: 0.1367 - val_accuracy: 0.9478 - val_auc_2: 0.9789
# Epoch 42/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1683 - accuracy: 0.9319 - auc_2: 0.9653 - val_loss: 0.1473 - val_accuracy: 0.9403 - val_auc_2: 0.9776
# Epoch 43/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1661 - accuracy: 0.9292 - auc_2: 0.9661 - val_loss: 0.1405 - val_accuracy: 0.9453 - val_auc_2: 0.9815
# Epoch 44/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1678 - accuracy: 0.9327 - auc_2: 0.9646 - val_loss: 0.1425 - val_accuracy: 0.9478 - val_auc_2: 0.9815
# Epoch 45/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1691 - accuracy: 0.9266 - auc_2: 0.9634 - val_loss: 0.1374 - val_accuracy: 0.9453 - val_auc_2: 0.9805
# Epoch 46/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1633 - accuracy: 0.9336 - auc_2: 0.9670 - val_loss: 0.1430 - val_accuracy: 0.9403 - val_auc_2: 0.9829
# Epoch 47/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1561 - accuracy: 0.9398 - auc_2: 0.9696 - val_loss: 0.1314 - val_accuracy: 0.9478 - val_auc_2: 0.9819
# Epoch 48/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1644 - accuracy: 0.9327 - auc_2: 0.9656 - val_loss: 0.1402 - val_accuracy: 0.9552 - val_auc_2: 0.9805
# Epoch 49/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1608 - accuracy: 0.9380 - auc_2: 0.9668 - val_loss: 0.1248 - val_accuracy: 0.9552 - val_auc_2: 0.9825
# Epoch 50/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1641 - accuracy: 0.9336 - auc_2: 0.9668 - val_loss: 0.1226 - val_accuracy: 0.9627 - val_auc_2: 0.9825
# Epoch 51/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1508 - accuracy: 0.9420 - auc_2: 0.9716 - val_loss: 0.1285 - val_accuracy: 0.9527 - val_auc_2: 0.9834
# Epoch 52/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1562 - accuracy: 0.9389 - auc_2: 0.9681 - val_loss: 0.1432 - val_accuracy: 0.9353 - val_auc_2: 0.9832
# Epoch 53/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1588 - accuracy: 0.9345 - auc_2: 0.9681 - val_loss: 0.1251 - val_accuracy: 0.9527 - val_auc_2: 0.9843
# Epoch 54/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1621 - accuracy: 0.9288 - auc_2: 0.9686 - val_loss: 0.1253 - val_accuracy: 0.9627 - val_auc_2: 0.9826
# Epoch 55/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.9301 - auc_2: 0.9670 - val_loss: 0.1336 - val_accuracy: 0.9478 - val_auc_2: 0.9818
# Epoch 56/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1496 - accuracy: 0.9393 - auc_2: 0.9722 - val_loss: 0.1162 - val_accuracy: 0.9602 - val_auc_2: 0.9801
# Epoch 57/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1538 - accuracy: 0.9389 - auc_2: 0.9698 - val_loss: 0.1123 - val_accuracy: 0.9652 - val_auc_2: 0.9848
# Epoch 58/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1546 - accuracy: 0.9385 - auc_2: 0.9681 - val_loss: 0.1149 - val_accuracy: 0.9652 - val_auc_2: 0.9830
# Epoch 59/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1478 - accuracy: 0.9437 - auc_2: 0.9731 - val_loss: 0.1211 - val_accuracy: 0.9627 - val_auc_2: 0.9818
# Epoch 60/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1520 - accuracy: 0.9380 - auc_2: 0.9716 - val_loss: 0.1234 - val_accuracy: 0.9552 - val_auc_2: 0.9827
# Epoch 61/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1476 - accuracy: 0.9371 - auc_2: 0.9739 - val_loss: 0.1141 - val_accuracy: 0.9652 - val_auc_2: 0.9847
# Epoch 62/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1463 - accuracy: 0.9420 - auc_2: 0.9737 - val_loss: 0.1102 - val_accuracy: 0.9627 - val_auc_2: 0.9856
# Epoch 63/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1490 - accuracy: 0.9407 - auc_2: 0.9719 - val_loss: 0.1218 - val_accuracy: 0.9478 - val_auc_2: 0.9853
# Epoch 64/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1578 - accuracy: 0.9367 - auc_2: 0.9679 - val_loss: 0.1183 - val_accuracy: 0.9677 - val_auc_2: 0.9841
# Epoch 65/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1335 - accuracy: 0.9424 - auc_2: 0.9791 - val_loss: 0.1110 - val_accuracy: 0.9577 - val_auc_2: 0.9798
# Epoch 66/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1527 - accuracy: 0.9363 - auc_2: 0.9686 - val_loss: 0.1216 - val_accuracy: 0.9502 - val_auc_2: 0.9860
# Epoch 67/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1371 - accuracy: 0.9433 - auc_2: 0.9778 - val_loss: 0.1142 - val_accuracy: 0.9502 - val_auc_2: 0.9839
# Epoch 68/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1409 - accuracy: 0.9407 - auc_2: 0.9746 - val_loss: 0.1117 - val_accuracy: 0.9652 - val_auc_2: 0.9852
# Epoch 69/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1391 - accuracy: 0.9446 - auc_2: 0.9764 - val_loss: 0.1142 - val_accuracy: 0.9577 - val_auc_2: 0.9852
# Epoch 70/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1351 - accuracy: 0.9473 - auc_2: 0.9752 - val_loss: 0.1114 - val_accuracy: 0.9627 - val_auc_2: 0.9849
# Epoch 71/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1484 - accuracy: 0.9363 - auc_2: 0.9735 - val_loss: 0.1139 - val_accuracy: 0.9627 - val_auc_2: 0.9863
# Epoch 72/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1362 - accuracy: 0.9451 - auc_2: 0.9755 - val_loss: 0.1156 - val_accuracy: 0.9527 - val_auc_2: 0.9846
# Epoch 73/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1354 - accuracy: 0.9420 - auc_2: 0.9778 - val_loss: 0.1119 - val_accuracy: 0.9577 - val_auc_2: 0.9838
# Epoch 74/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9499 - auc_2: 0.9820 - val_loss: 0.1031 - val_accuracy: 0.9602 - val_auc_2: 0.9863
# Epoch 75/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1418 - accuracy: 0.9429 - auc_2: 0.9752 - val_loss: 0.1144 - val_accuracy: 0.9502 - val_auc_2: 0.9844
# Epoch 76/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1266 - accuracy: 0.9429 - auc_2: 0.9799 - val_loss: 0.1100 - val_accuracy: 0.9627 - val_auc_2: 0.9848
# Epoch 77/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1275 - accuracy: 0.9468 - auc_2: 0.9781 - val_loss: 0.1113 - val_accuracy: 0.9527 - val_auc_2: 0.9840
# Epoch 78/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9473 - auc_2: 0.9766 - val_loss: 0.1060 - val_accuracy: 0.9627 - val_auc_2: 0.9844
# Epoch 79/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9512 - auc_2: 0.9824 - val_loss: 0.1162 - val_accuracy: 0.9577 - val_auc_2: 0.9830
# Epoch 80/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1355 - accuracy: 0.9437 - auc_2: 0.9771 - val_loss: 0.1250 - val_accuracy: 0.9353 - val_auc_2: 0.9828
# Epoch 81/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1369 - accuracy: 0.9354 - auc_2: 0.9779 - val_loss: 0.1150 - val_accuracy: 0.9577 - val_auc_2: 0.9835
# Epoch 82/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1330 - accuracy: 0.9442 - auc_2: 0.9774 - val_loss: 0.1058 - val_accuracy: 0.9726 - val_auc_2: 0.9863
# Epoch 83/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1263 - accuracy: 0.9477 - auc_2: 0.9799 - val_loss: 0.1086 - val_accuracy: 0.9552 - val_auc_2: 0.9855
# Epoch 84/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1198 - accuracy: 0.9459 - auc_2: 0.9800 - val_loss: 0.1172 - val_accuracy: 0.9428 - val_auc_2: 0.9820
# Epoch 85/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9473 - auc_2: 0.9793 - val_loss: 0.1059 - val_accuracy: 0.9602 - val_auc_2: 0.9857
# Epoch 86/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1265 - accuracy: 0.9446 - auc_2: 0.9806 - val_loss: 0.1088 - val_accuracy: 0.9602 - val_auc_2: 0.9858
# Epoch 87/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1321 - accuracy: 0.9451 - auc_2: 0.9785 - val_loss: 0.1140 - val_accuracy: 0.9478 - val_auc_2: 0.9858
# Epoch 88/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1308 - accuracy: 0.9442 - auc_2: 0.9771 - val_loss: 0.1096 - val_accuracy: 0.9552 - val_auc_2: 0.9858
# Epoch 89/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1248 - accuracy: 0.9490 - auc_2: 0.9797 - val_loss: 0.1025 - val_accuracy: 0.9577 - val_auc_2: 0.9857
# Epoch 90/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1294 - accuracy: 0.9477 - auc_2: 0.9795 - val_loss: 0.1041 - val_accuracy: 0.9577 - val_auc_2: 0.9853
# Epoch 91/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1246 - accuracy: 0.9437 - auc_2: 0.9801 - val_loss: 0.1107 - val_accuracy: 0.9527 - val_auc_2: 0.9790
# Epoch 92/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 0.9547 - auc_2: 0.9846 - val_loss: 0.1012 - val_accuracy: 0.9677 - val_auc_2: 0.9861
# Epoch 93/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1192 - accuracy: 0.9468 - auc_2: 0.9829 - val_loss: 0.1094 - val_accuracy: 0.9502 - val_auc_2: 0.9795
# Epoch 94/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1253 - accuracy: 0.9429 - auc_2: 0.9798 - val_loss: 0.1131 - val_accuracy: 0.9577 - val_auc_2: 0.9851
# Epoch 95/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1124 - accuracy: 0.9574 - auc_2: 0.9837 - val_loss: 0.1104 - val_accuracy: 0.9502 - val_auc_2: 0.9839
# Epoch 96/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1178 - accuracy: 0.9547 - auc_2: 0.9818 - val_loss: 0.1099 - val_accuracy: 0.9602 - val_auc_2: 0.9843
# Epoch 97/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1205 - accuracy: 0.9508 - auc_2: 0.9809 - val_loss: 0.1021 - val_accuracy: 0.9701 - val_auc_2: 0.9858
# Epoch 98/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 0.9420 - auc_2: 0.9814 - val_loss: 0.1050 - val_accuracy: 0.9726 - val_auc_2: 0.9877
# Epoch 99/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1165 - accuracy: 0.9543 - auc_2: 0.9831 - val_loss: 0.1042 - val_accuracy: 0.9677 - val_auc_2: 0.9856
# Epoch 100/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1202 - accuracy: 0.9481 - auc_2: 0.9828 - val_loss: 0.1050 - val_accuracy: 0.9701 - val_auc_2: 0.9870
# Epoch 101/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1161 - accuracy: 0.9530 - auc_2: 0.9821 - val_loss: 0.1022 - val_accuracy: 0.9652 - val_auc_2: 0.9872
# Epoch 102/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1172 - accuracy: 0.9503 - auc_2: 0.9820 - val_loss: 0.1019 - val_accuracy: 0.9726 - val_auc_2: 0.9825
# Epoch 103/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1152 - accuracy: 0.9503 - auc_2: 0.9830 - val_loss: 0.1072 - val_accuracy: 0.9677 - val_auc_2: 0.9859
# Epoch 104/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1160 - accuracy: 0.9490 - auc_2: 0.9822 - val_loss: 0.1055 - val_accuracy: 0.9701 - val_auc_2: 0.9857
# Epoch 105/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1118 - accuracy: 0.9534 - auc_2: 0.9840 - val_loss: 0.1078 - val_accuracy: 0.9552 - val_auc_2: 0.9795
# Epoch 106/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1138 - accuracy: 0.9490 - auc_2: 0.9828 - val_loss: 0.1022 - val_accuracy: 0.9652 - val_auc_2: 0.9861
# Epoch 107/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9609 - auc_2: 0.9876 - val_loss: 0.1013 - val_accuracy: 0.9577 - val_auc_2: 0.9854
# Epoch 108/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1125 - accuracy: 0.9574 - auc_2: 0.9826 - val_loss: 0.1044 - val_accuracy: 0.9602 - val_auc_2: 0.9865
# Epoch 109/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.9530 - auc_2: 0.9855 - val_loss: 0.1012 - val_accuracy: 0.9726 - val_auc_2: 0.9808
# Epoch 110/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 0.9547 - auc_2: 0.9815 - val_loss: 0.1017 - val_accuracy: 0.9677 - val_auc_2: 0.9865
# Epoch 111/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1092 - accuracy: 0.9552 - auc_2: 0.9843 - val_loss: 0.0979 - val_accuracy: 0.9701 - val_auc_2: 0.9878
# Epoch 112/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1134 - accuracy: 0.9512 - auc_2: 0.9830 - val_loss: 0.1021 - val_accuracy: 0.9701 - val_auc_2: 0.9867
# Epoch 113/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.9459 - auc_2: 0.9820 - val_loss: 0.1028 - val_accuracy: 0.9652 - val_auc_2: 0.9859
# Epoch 114/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 0.9552 - auc_2: 0.9800 - val_loss: 0.0982 - val_accuracy: 0.9726 - val_auc_2: 0.9882
# Epoch 115/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.9604 - auc_2: 0.9845 - val_loss: 0.0953 - val_accuracy: 0.9701 - val_auc_2: 0.9873
# Epoch 116/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1192 - accuracy: 0.9481 - auc_2: 0.9823 - val_loss: 0.1036 - val_accuracy: 0.9627 - val_auc_2: 0.9860
# Epoch 117/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1105 - accuracy: 0.9560 - auc_2: 0.9827 - val_loss: 0.1020 - val_accuracy: 0.9701 - val_auc_2: 0.9852
# Epoch 118/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1160 - accuracy: 0.9499 - auc_2: 0.9827 - val_loss: 0.0970 - val_accuracy: 0.9677 - val_auc_2: 0.9869
# Epoch 119/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1081 - accuracy: 0.9538 - auc_2: 0.9861 - val_loss: 0.1025 - val_accuracy: 0.9677 - val_auc_2: 0.9867
# Epoch 120/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1060 - accuracy: 0.9552 - auc_2: 0.9865 - val_loss: 0.1000 - val_accuracy: 0.9652 - val_auc_2: 0.9859
# Epoch 121/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1059 - accuracy: 0.9543 - auc_2: 0.9846 - val_loss: 0.0974 - val_accuracy: 0.9701 - val_auc_2: 0.9862
# Epoch 122/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1172 - accuracy: 0.9477 - auc_2: 0.9823 - val_loss: 0.1043 - val_accuracy: 0.9751 - val_auc_2: 0.9861
# Epoch 123/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1038 - accuracy: 0.9582 - auc_2: 0.9870 - val_loss: 0.1014 - val_accuracy: 0.9701 - val_auc_2: 0.9862
# Epoch 124/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1143 - accuracy: 0.9556 - auc_2: 0.9816 - val_loss: 0.1046 - val_accuracy: 0.9677 - val_auc_2: 0.9860
# Epoch 125/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1121 - accuracy: 0.9574 - auc_2: 0.9828 - val_loss: 0.1033 - val_accuracy: 0.9677 - val_auc_2: 0.9864
# Epoch 126/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1090 - accuracy: 0.9578 - auc_2: 0.9850 - val_loss: 0.1015 - val_accuracy: 0.9627 - val_auc_2: 0.9860
# Epoch 127/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1125 - accuracy: 0.9508 - auc_2: 0.9846 - val_loss: 0.1017 - val_accuracy: 0.9701 - val_auc_2: 0.9855
# Epoch 128/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1045 - accuracy: 0.9560 - auc_2: 0.9871 - val_loss: 0.0967 - val_accuracy: 0.9726 - val_auc_2: 0.9865
# Epoch 129/500
# 72/72 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9549 - auc_2: 0.98 - 0s 3ms/step - loss: 0.1035 - accuracy: 0.9547 - auc_2: 0.9872 - val_loss: 0.0982 - val_accuracy: 0.9677 - val_auc_2: 0.9879
# Epoch 130/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1023 - accuracy: 0.9552 - auc_2: 0.9855 - val_loss: 0.1023 - val_accuracy: 0.9701 - val_auc_2: 0.9854
# Epoch 131/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9521 - auc_2: 0.9863 - val_loss: 0.1022 - val_accuracy: 0.9701 - val_auc_2: 0.9869
# Epoch 132/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1076 - accuracy: 0.9512 - auc_2: 0.9839 - val_loss: 0.1027 - val_accuracy: 0.9652 - val_auc_2: 0.9854
# Epoch 133/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 0.9618 - auc_2: 0.9890 - val_loss: 0.1037 - val_accuracy: 0.9677 - val_auc_2: 0.9794
# Epoch 134/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0977 - accuracy: 0.9565 - auc_2: 0.9865 - val_loss: 0.0973 - val_accuracy: 0.9677 - val_auc_2: 0.9877
# Epoch 135/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1007 - accuracy: 0.9600 - auc_2: 0.9874 - val_loss: 0.0940 - val_accuracy: 0.9701 - val_auc_2: 0.9866
# Epoch 136/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9582 - auc_2: 0.9878 - val_loss: 0.1022 - val_accuracy: 0.9701 - val_auc_2: 0.9845
# Epoch 137/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0977 - accuracy: 0.9574 - auc_2: 0.9877 - val_loss: 0.0976 - val_accuracy: 0.9701 - val_auc_2: 0.9861
# Epoch 138/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1031 - accuracy: 0.9538 - auc_2: 0.9864 - val_loss: 0.1011 - val_accuracy: 0.9701 - val_auc_2: 0.9866
# Epoch 139/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1127 - accuracy: 0.9534 - auc_2: 0.9842 - val_loss: 0.0989 - val_accuracy: 0.9751 - val_auc_2: 0.9878
# Epoch 140/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1024 - accuracy: 0.9569 - auc_2: 0.9867 - val_loss: 0.0979 - val_accuracy: 0.9726 - val_auc_2: 0.9876
# Epoch 141/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0990 - accuracy: 0.9565 - auc_2: 0.9863 - val_loss: 0.1029 - val_accuracy: 0.9652 - val_auc_2: 0.9864
# Epoch 142/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1004 - accuracy: 0.9578 - auc_2: 0.9855 - val_loss: 0.1006 - val_accuracy: 0.9677 - val_auc_2: 0.9859
# Epoch 143/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0971 - accuracy: 0.9596 - auc_2: 0.9875 - val_loss: 0.0984 - val_accuracy: 0.9652 - val_auc_2: 0.9855
# Epoch 144/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0993 - accuracy: 0.9574 - auc_2: 0.9884 - val_loss: 0.0973 - val_accuracy: 0.9701 - val_auc_2: 0.9881
# Epoch 145/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0908 - accuracy: 0.9635 - auc_2: 0.9894 - val_loss: 0.0981 - val_accuracy: 0.9652 - val_auc_2: 0.9869
# Epoch 146/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9604 - auc_2: 0.9884 - val_loss: 0.1020 - val_accuracy: 0.9627 - val_auc_2: 0.9852
# Epoch 147/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0897 - accuracy: 0.9631 - auc_2: 0.9902 - val_loss: 0.0954 - val_accuracy: 0.9652 - val_auc_2: 0.9879
# Epoch 148/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0940 - accuracy: 0.9622 - auc_2: 0.9872 - val_loss: 0.1037 - val_accuracy: 0.9602 - val_auc_2: 0.9847
# Epoch 149/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1073 - accuracy: 0.9556 - auc_2: 0.9859 - val_loss: 0.1059 - val_accuracy: 0.9677 - val_auc_2: 0.9849
# Epoch 150/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0918 - accuracy: 0.9604 - auc_2: 0.9888 - val_loss: 0.0974 - val_accuracy: 0.9652 - val_auc_2: 0.9868
# Epoch 151/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0990 - accuracy: 0.9574 - auc_2: 0.9875 - val_loss: 0.1157 - val_accuracy: 0.9502 - val_auc_2: 0.9850
# Epoch 152/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0947 - accuracy: 0.9565 - auc_2: 0.9895 - val_loss: 0.1078 - val_accuracy: 0.9627 - val_auc_2: 0.9836
# Epoch 153/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1119 - accuracy: 0.9547 - auc_2: 0.9846 - val_loss: 0.1050 - val_accuracy: 0.9627 - val_auc_2: 0.9841
# Epoch 154/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.9538 - auc_2: 0.9854 - val_loss: 0.1039 - val_accuracy: 0.9677 - val_auc_2: 0.9859
# Epoch 155/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0975 - accuracy: 0.9538 - auc_2: 0.9865 - val_loss: 0.1041 - val_accuracy: 0.9677 - val_auc_2: 0.9845
# Epoch 156/500
# 72/72 [==============================] - 0s 4ms/step - loss: 0.1023 - accuracy: 0.9565 - auc_2: 0.9857 - val_loss: 0.1057 - val_accuracy: 0.9677 - val_auc_2: 0.9848
# Epoch 157/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1010 - accuracy: 0.9525 - auc_2: 0.9873 - val_loss: 0.0986 - val_accuracy: 0.9677 - val_auc_2: 0.9869
# Epoch 158/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0949 - accuracy: 0.9556 - auc_2: 0.9893 - val_loss: 0.0982 - val_accuracy: 0.9652 - val_auc_2: 0.9863
# Epoch 159/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.9596 - auc_2: 0.9858 - val_loss: 0.1001 - val_accuracy: 0.9652 - val_auc_2: 0.9856
# Epoch 160/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.9609 - auc_2: 0.9886 - val_loss: 0.0961 - val_accuracy: 0.9677 - val_auc_2: 0.9860
# Epoch 161/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1091 - accuracy: 0.9525 - auc_2: 0.9839 - val_loss: 0.0986 - val_accuracy: 0.9627 - val_auc_2: 0.9866
# Epoch 162/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.1028 - accuracy: 0.9547 - auc_2: 0.9862 - val_loss: 0.0966 - val_accuracy: 0.9726 - val_auc_2: 0.9876
# Epoch 163/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.9613 - auc_2: 0.9921 - val_loss: 0.0954 - val_accuracy: 0.9652 - val_auc_2: 0.9864
# Epoch 164/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 0.9578 - auc_2: 0.9891 - val_loss: 0.1027 - val_accuracy: 0.9602 - val_auc_2: 0.9844
# Epoch 165/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.9543 - auc_2: 0.9854 - val_loss: 0.0916 - val_accuracy: 0.9677 - val_auc_2: 0.9886
# Epoch 166/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0978 - accuracy: 0.9587 - auc_2: 0.9866 - val_loss: 0.1040 - val_accuracy: 0.9677 - val_auc_2: 0.9840
# Epoch 167/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0991 - accuracy: 0.9587 - auc_2: 0.9878 - val_loss: 0.0979 - val_accuracy: 0.9677 - val_auc_2: 0.9865
# Epoch 168/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.1022 - accuracy: 0.9578 - auc_2: 0.9872 - val_loss: 0.1047 - val_accuracy: 0.9652 - val_auc_2: 0.9807
# Epoch 169/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9622 - auc_2: 0.9879 - val_loss: 0.0938 - val_accuracy: 0.9677 - val_auc_2: 0.9878
# Epoch 170/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 0.9609 - auc_2: 0.9873 - val_loss: 0.0996 - val_accuracy: 0.9677 - val_auc_2: 0.9881
# Epoch 171/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0914 - accuracy: 0.9653 - auc_2: 0.9863 - val_loss: 0.0916 - val_accuracy: 0.9677 - val_auc_2: 0.9876
# Epoch 172/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0903 - accuracy: 0.9591 - auc_2: 0.9894 - val_loss: 0.0915 - val_accuracy: 0.9677 - val_auc_2: 0.9881
# Epoch 173/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0853 - accuracy: 0.9622 - auc_2: 0.9901 - val_loss: 0.0978 - val_accuracy: 0.9677 - val_auc_2: 0.9872
# Epoch 174/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0927 - accuracy: 0.9613 - auc_2: 0.9866 - val_loss: 0.0917 - val_accuracy: 0.9726 - val_auc_2: 0.9889
# Epoch 175/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0939 - accuracy: 0.9565 - auc_2: 0.9883 - val_loss: 0.1011 - val_accuracy: 0.9602 - val_auc_2: 0.9871
# Epoch 176/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0965 - accuracy: 0.9578 - auc_2: 0.9885 - val_loss: 0.1021 - val_accuracy: 0.9602 - val_auc_2: 0.9849
# Epoch 177/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0988 - accuracy: 0.9582 - auc_2: 0.9888 - val_loss: 0.0922 - val_accuracy: 0.9701 - val_auc_2: 0.9882
# Epoch 178/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9582 - auc_2: 0.9887 - val_loss: 0.0942 - val_accuracy: 0.9677 - val_auc_2: 0.9878
# Epoch 179/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0969 - accuracy: 0.9604 - auc_2: 0.9881 - val_loss: 0.0963 - val_accuracy: 0.9677 - val_auc_2: 0.9874
# Epoch 180/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0956 - accuracy: 0.9600 - auc_2: 0.9875 - val_loss: 0.0948 - val_accuracy: 0.9677 - val_auc_2: 0.9882
# Epoch 181/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 0.9635 - auc_2: 0.9888 - val_loss: 0.0988 - val_accuracy: 0.9652 - val_auc_2: 0.9860
# Epoch 182/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0856 - accuracy: 0.9644 - auc_2: 0.9905 - val_loss: 0.0928 - val_accuracy: 0.9652 - val_auc_2: 0.9876
# Epoch 183/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0889 - accuracy: 0.9635 - auc_2: 0.9874 - val_loss: 0.0924 - val_accuracy: 0.9652 - val_auc_2: 0.9882
# Epoch 184/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 0.9635 - auc_2: 0.9900 - val_loss: 0.0920 - val_accuracy: 0.9677 - val_auc_2: 0.9884
# Epoch 185/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.9653 - auc_2: 0.9919 - val_loss: 0.0933 - val_accuracy: 0.9677 - val_auc_2: 0.9877
# Epoch 186/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.9657 - auc_2: 0.9909 - val_loss: 0.0918 - val_accuracy: 0.9677 - val_auc_2: 0.9872
# Epoch 187/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0947 - accuracy: 0.9591 - auc_2: 0.9869 - val_loss: 0.0900 - val_accuracy: 0.9701 - val_auc_2: 0.9893
# Epoch 188/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0861 - accuracy: 0.9679 - auc_2: 0.9901 - val_loss: 0.0915 - val_accuracy: 0.9652 - val_auc_2: 0.9869
# Epoch 189/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9618 - auc_2: 0.9913 - val_loss: 0.0864 - val_accuracy: 0.9677 - val_auc_2: 0.9894
# Epoch 190/500
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 0.9604 - auc_2: 0.9894 - val_loss: 0.0941 - val_accuracy: 0.9652 - val_auc_2: 0.9861
# Epoch 191/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.9626 - auc_2: 0.9885 - val_loss: 0.0886 - val_accuracy: 0.9751 - val_auc_2: 0.9880
# Epoch 192/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0936 - accuracy: 0.9569 - auc_2: 0.9892 - val_loss: 0.0928 - val_accuracy: 0.9677 - val_auc_2: 0.9870
# Epoch 193/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9640 - auc_2: 0.9914 - val_loss: 0.0977 - val_accuracy: 0.9677 - val_auc_2: 0.9863
# Epoch 194/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9657 - auc_2: 0.9911 - val_loss: 0.0889 - val_accuracy: 0.9701 - val_auc_2: 0.9880
# Epoch 195/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0889 - accuracy: 0.9631 - auc_2: 0.9893 - val_loss: 0.0986 - val_accuracy: 0.9652 - val_auc_2: 0.9867
# Epoch 196/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0864 - accuracy: 0.9644 - auc_2: 0.9900 - val_loss: 0.0896 - val_accuracy: 0.9726 - val_auc_2: 0.9878
# Epoch 197/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0829 - accuracy: 0.9662 - auc_2: 0.9907 - val_loss: 0.0920 - val_accuracy: 0.9751 - val_auc_2: 0.9881
# Epoch 198/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0914 - accuracy: 0.9604 - auc_2: 0.9882 - val_loss: 0.0905 - val_accuracy: 0.9726 - val_auc_2: 0.9882
# Epoch 199/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0859 - accuracy: 0.9600 - auc_2: 0.9900 - val_loss: 0.0911 - val_accuracy: 0.9726 - val_auc_2: 0.9890
# Epoch 200/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9657 - auc_2: 0.9920 - val_loss: 0.0946 - val_accuracy: 0.9701 - val_auc_2: 0.9873
# Epoch 201/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0868 - accuracy: 0.9675 - auc_2: 0.9879 - val_loss: 0.0996 - val_accuracy: 0.9677 - val_auc_2: 0.9862
# Epoch 202/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0818 - accuracy: 0.9640 - auc_2: 0.9920 - val_loss: 0.0910 - val_accuracy: 0.9751 - val_auc_2: 0.9882
# Epoch 203/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0940 - accuracy: 0.9591 - auc_2: 0.9865 - val_loss: 0.0987 - val_accuracy: 0.9652 - val_auc_2: 0.9866
# Epoch 204/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.9622 - auc_2: 0.9894 - val_loss: 0.0921 - val_accuracy: 0.9701 - val_auc_2: 0.9889
# Epoch 205/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 0.9640 - auc_2: 0.9900 - val_loss: 0.0944 - val_accuracy: 0.9602 - val_auc_2: 0.9881
# Epoch 206/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.9591 - auc_2: 0.9878 - val_loss: 0.0979 - val_accuracy: 0.9627 - val_auc_2: 0.9878
# Epoch 207/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0885 - accuracy: 0.9609 - auc_2: 0.9903 - val_loss: 0.0888 - val_accuracy: 0.9652 - val_auc_2: 0.9889
# Epoch 208/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 0.9675 - auc_2: 0.9902 - val_loss: 0.0870 - val_accuracy: 0.9701 - val_auc_2: 0.9897
# Epoch 209/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9644 - auc_2: 0.9894 - val_loss: 0.0937 - val_accuracy: 0.9751 - val_auc_2: 0.9868
# Epoch 210/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0865 - accuracy: 0.9613 - auc_2: 0.9911 - val_loss: 0.0965 - val_accuracy: 0.9627 - val_auc_2: 0.9875
# Epoch 211/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9631 - auc_2: 0.9911 - val_loss: 0.1030 - val_accuracy: 0.9602 - val_auc_2: 0.9855
# Epoch 212/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.9692 - auc_2: 0.9920 - val_loss: 0.1038 - val_accuracy: 0.9652 - val_auc_2: 0.9845
# Epoch 213/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 0.9657 - auc_2: 0.9902 - val_loss: 0.0994 - val_accuracy: 0.9602 - val_auc_2: 0.9865
# Epoch 214/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0857 - accuracy: 0.9609 - auc_2: 0.9909 - val_loss: 0.0910 - val_accuracy: 0.9726 - val_auc_2: 0.9824
# Epoch 215/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0846 - accuracy: 0.9662 - auc_2: 0.9895 - val_loss: 0.0964 - val_accuracy: 0.9677 - val_auc_2: 0.9871
# Epoch 216/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0889 - accuracy: 0.9640 - auc_2: 0.9906 - val_loss: 0.0900 - val_accuracy: 0.9701 - val_auc_2: 0.9886
# Epoch 217/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9635 - auc_2: 0.9920 - val_loss: 0.0880 - val_accuracy: 0.9776 - val_auc_2: 0.9883
# Epoch 218/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0836 - accuracy: 0.9618 - auc_2: 0.9909 - val_loss: 0.0939 - val_accuracy: 0.9726 - val_auc_2: 0.9865
# Epoch 219/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9635 - auc_2: 0.9914 - val_loss: 0.0881 - val_accuracy: 0.9627 - val_auc_2: 0.9890
# Epoch 220/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0873 - accuracy: 0.9618 - auc_2: 0.9894 - val_loss: 0.0956 - val_accuracy: 0.9652 - val_auc_2: 0.9875
# Epoch 221/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0850 - accuracy: 0.9653 - auc_2: 0.9902 - val_loss: 0.0985 - val_accuracy: 0.9701 - val_auc_2: 0.9859
# Epoch 222/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9618 - auc_2: 0.9880 - val_loss: 0.0964 - val_accuracy: 0.9627 - val_auc_2: 0.9883
# Epoch 223/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9613 - auc_2: 0.9909 - val_loss: 0.0901 - val_accuracy: 0.9677 - val_auc_2: 0.9888
# Epoch 224/500
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0852 - accuracy: 0.9635 - auc_2: 0.9909 - val_loss: 0.0939 - val_accuracy: 0.9652 - val_auc_2: 0.9878
# Epoch 225/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9644 - auc_2: 0.9925 - val_loss: 0.0914 - val_accuracy: 0.9652 - val_auc_2: 0.9882
# Epoch 226/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9648 - auc_2: 0.9911 - val_loss: 0.0913 - val_accuracy: 0.9751 - val_auc_2: 0.9881
# Epoch 227/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0806 - accuracy: 0.9640 - auc_2: 0.9924 - val_loss: 0.0952 - val_accuracy: 0.9701 - val_auc_2: 0.9885
# Epoch 228/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0823 - accuracy: 0.9648 - auc_2: 0.9920 - val_loss: 0.0924 - val_accuracy: 0.9726 - val_auc_2: 0.9884
# Epoch 229/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0862 - accuracy: 0.9604 - auc_2: 0.9903 - val_loss: 0.0960 - val_accuracy: 0.9652 - val_auc_2: 0.9874
# Epoch 230/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0873 - accuracy: 0.9591 - auc_2: 0.9907 - val_loss: 0.0958 - val_accuracy: 0.9726 - val_auc_2: 0.9872
# Epoch 231/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0779 - accuracy: 0.9675 - auc_2: 0.9928 - val_loss: 0.0902 - val_accuracy: 0.9652 - val_auc_2: 0.9899
# Epoch 232/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0928 - accuracy: 0.9604 - auc_2: 0.9884 - val_loss: 0.0977 - val_accuracy: 0.9652 - val_auc_2: 0.9865
# Epoch 233/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0927 - accuracy: 0.9565 - auc_2: 0.9899 - val_loss: 0.0978 - val_accuracy: 0.9677 - val_auc_2: 0.9870
# Epoch 234/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9635 - auc_2: 0.9899 - val_loss: 0.1062 - val_accuracy: 0.9652 - val_auc_2: 0.9842
# Epoch 235/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.9618 - auc_2: 0.9897 - val_loss: 0.0978 - val_accuracy: 0.9726 - val_auc_2: 0.9867
# Epoch 236/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9622 - auc_2: 0.9909 - val_loss: 0.0955 - val_accuracy: 0.9677 - val_auc_2: 0.9866
# Epoch 237/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0885 - accuracy: 0.9600 - auc_2: 0.9892 - val_loss: 0.1053 - val_accuracy: 0.9652 - val_auc_2: 0.9805
# Epoch 238/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9609 - auc_2: 0.9901 - val_loss: 0.1006 - val_accuracy: 0.9701 - val_auc_2: 0.9875
# Epoch 239/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0849 - accuracy: 0.9600 - auc_2: 0.9914 - val_loss: 0.0884 - val_accuracy: 0.9726 - val_auc_2: 0.9888
# Epoch 240/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.9684 - auc_2: 0.9904 - val_loss: 0.0916 - val_accuracy: 0.9677 - val_auc_2: 0.9887
# Epoch 241/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.9644 - auc_2: 0.9917 - val_loss: 0.0856 - val_accuracy: 0.9726 - val_auc_2: 0.9892
# Epoch 242/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0996 - accuracy: 0.9569 - auc_2: 0.9868 - val_loss: 0.0989 - val_accuracy: 0.9701 - val_auc_2: 0.9880
# Epoch 243/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.9635 - auc_2: 0.9914 - val_loss: 0.0891 - val_accuracy: 0.9677 - val_auc_2: 0.9881
# Epoch 244/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0812 - accuracy: 0.9657 - auc_2: 0.9898 - val_loss: 0.0942 - val_accuracy: 0.9627 - val_auc_2: 0.9876
# Epoch 245/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0967 - accuracy: 0.9604 - auc_2: 0.9880 - val_loss: 0.0916 - val_accuracy: 0.9701 - val_auc_2: 0.9880
# Epoch 246/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0912 - accuracy: 0.9622 - auc_2: 0.9884 - val_loss: 0.0955 - val_accuracy: 0.9677 - val_auc_2: 0.9884
# Epoch 247/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0797 - accuracy: 0.9675 - auc_2: 0.9910 - val_loss: 0.0923 - val_accuracy: 0.9677 - val_auc_2: 0.9877
# Epoch 248/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0789 - accuracy: 0.9701 - auc_2: 0.9917 - val_loss: 0.0932 - val_accuracy: 0.9627 - val_auc_2: 0.9879
# Epoch 249/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.9631 - auc_2: 0.9919 - val_loss: 0.0934 - val_accuracy: 0.9677 - val_auc_2: 0.9878
# Epoch 250/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0896 - accuracy: 0.9635 - auc_2: 0.9876 - val_loss: 0.0897 - val_accuracy: 0.9701 - val_auc_2: 0.9890
# Epoch 251/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9662 - auc_2: 0.9922 - val_loss: 0.0824 - val_accuracy: 0.9776 - val_auc_2: 0.9899
# Epoch 252/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9635 - auc_2: 0.9900 - val_loss: 0.0899 - val_accuracy: 0.9701 - val_auc_2: 0.9882
# Epoch 253/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0837 - accuracy: 0.9626 - auc_2: 0.9906 - val_loss: 0.0964 - val_accuracy: 0.9652 - val_auc_2: 0.9870
# Epoch 254/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9622 - auc_2: 0.9904 - val_loss: 0.0988 - val_accuracy: 0.9652 - val_auc_2: 0.9871
# Epoch 255/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0898 - accuracy: 0.9578 - auc_2: 0.9905 - val_loss: 0.0951 - val_accuracy: 0.9701 - val_auc_2: 0.9878
# Epoch 256/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 0.9688 - auc_2: 0.9939 - val_loss: 0.0979 - val_accuracy: 0.9701 - val_auc_2: 0.9805
# Epoch 257/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.9600 - auc_2: 0.9898 - val_loss: 0.0982 - val_accuracy: 0.9751 - val_auc_2: 0.9881
# Epoch 258/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9648 - auc_2: 0.9904 - val_loss: 0.1043 - val_accuracy: 0.9652 - val_auc_2: 0.9864
# Epoch 259/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9662 - auc_2: 0.9901 - val_loss: 0.0981 - val_accuracy: 0.9677 - val_auc_2: 0.9867
# Epoch 260/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0850 - accuracy: 0.9657 - auc_2: 0.9912 - val_loss: 0.0927 - val_accuracy: 0.9677 - val_auc_2: 0.9878
# Epoch 261/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9701 - auc_2: 0.9943 - val_loss: 0.0916 - val_accuracy: 0.9677 - val_auc_2: 0.9882
# Epoch 262/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.9653 - auc_2: 0.9917 - val_loss: 0.0951 - val_accuracy: 0.9751 - val_auc_2: 0.9872
# Epoch 263/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9666 - auc_2: 0.9930 - val_loss: 0.0961 - val_accuracy: 0.9677 - val_auc_2: 0.9875
# Epoch 264/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0854 - accuracy: 0.9613 - auc_2: 0.9903 - val_loss: 0.0900 - val_accuracy: 0.9726 - val_auc_2: 0.9876
# Epoch 265/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0837 - accuracy: 0.9648 - auc_2: 0.9906 - val_loss: 0.0952 - val_accuracy: 0.9726 - val_auc_2: 0.9875
# Epoch 266/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0841 - accuracy: 0.9653 - auc_2: 0.9885 - val_loss: 0.0908 - val_accuracy: 0.9701 - val_auc_2: 0.9883
# Epoch 267/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0754 - accuracy: 0.9662 - auc_2: 0.9935 - val_loss: 0.0903 - val_accuracy: 0.9701 - val_auc_2: 0.9874
# Epoch 268/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9648 - auc_2: 0.9928 - val_loss: 0.0990 - val_accuracy: 0.9652 - val_auc_2: 0.9869
# Epoch 269/500
# ...
# Epoch 412/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9697 - auc_2: 0.9942 - val_loss: 0.0896 - val_accuracy: 0.9677 - val_auc_2: 0.9836
# Epoch 413/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0734 - accuracy: 0.9670 - auc_2: 0.9916 - val_loss: 0.0945 - val_accuracy: 0.9726 - val_auc_2: 0.9748
# Epoch 414/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9675 - auc_2: 0.9926 - val_loss: 0.0950 - val_accuracy: 0.9701 - val_auc_2: 0.9812
# Epoch 415/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 0.9701 - auc_2: 0.9938 - val_loss: 0.0877 - val_accuracy: 0.9701 - val_auc_2: 0.9828
# Epoch 416/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 0.9679 - auc_2: 0.9926 - val_loss: 0.0951 - val_accuracy: 0.9677 - val_auc_2: 0.9813
# Epoch 417/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0721 - accuracy: 0.9692 - auc_2: 0.9913 - val_loss: 0.0917 - val_accuracy: 0.9701 - val_auc_2: 0.9818
# Epoch 418/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9675 - auc_2: 0.9945 - val_loss: 0.0887 - val_accuracy: 0.9726 - val_auc_2: 0.9887
# Epoch 419/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0670 - accuracy: 0.9710 - auc_2: 0.9939 - val_loss: 0.0920 - val_accuracy: 0.9726 - val_auc_2: 0.9817
# Epoch 420/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9697 - auc_2: 0.9934 - val_loss: 0.0957 - val_accuracy: 0.9751 - val_auc_2: 0.9753
# Epoch 421/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 0.9710 - auc_2: 0.9938 - val_loss: 0.0871 - val_accuracy: 0.9726 - val_auc_2: 0.9897
# Epoch 422/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0674 - accuracy: 0.9705 - auc_2: 0.9946 - val_loss: 0.0884 - val_accuracy: 0.9751 - val_auc_2: 0.9891
# Epoch 423/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0779 - accuracy: 0.9626 - auc_2: 0.9930 - val_loss: 0.0923 - val_accuracy: 0.9726 - val_auc_2: 0.9822
# Epoch 424/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0762 - accuracy: 0.9653 - auc_2: 0.9931 - val_loss: 0.0967 - val_accuracy: 0.9801 - val_auc_2: 0.9744
# Epoch 425/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 0.9675 - auc_2: 0.9931 - val_loss: 0.0918 - val_accuracy: 0.9751 - val_auc_2: 0.9883
# Epoch 426/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9697 - auc_2: 0.9934 - val_loss: 0.0938 - val_accuracy: 0.9701 - val_auc_2: 0.9874
# Epoch 427/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0698 - accuracy: 0.9688 - auc_2: 0.9941 - val_loss: 0.0964 - val_accuracy: 0.9701 - val_auc_2: 0.9817
# Epoch 428/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0742 - accuracy: 0.9675 - auc_2: 0.9925 - val_loss: 0.0932 - val_accuracy: 0.9751 - val_auc_2: 0.9819
# Epoch 429/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0752 - accuracy: 0.9670 - auc_2: 0.9913 - val_loss: 0.0951 - val_accuracy: 0.9726 - val_auc_2: 0.9886
# Epoch 430/500
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0731 - accuracy: 0.9662 - auc_2: 0.9925 - val_loss: 0.0924 - val_accuracy: 0.9776 - val_auc_2: 0.9832
# Epoch 431/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0657 - accuracy: 0.9719 - auc_2: 0.9949 - val_loss: 0.0876 - val_accuracy: 0.9776 - val_auc_2: 0.9836
# Epoch 432/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0677 - accuracy: 0.9697 - auc_2: 0.9944 - val_loss: 0.0911 - val_accuracy: 0.9776 - val_auc_2: 0.9767
# Epoch 433/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9675 - auc_2: 0.9935 - val_loss: 0.0928 - val_accuracy: 0.9677 - val_auc_2: 0.9840
# Epoch 434/500
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0633 - accuracy: 0.9714 - auc_2: 0.9940 - val_loss: 0.0911 - val_accuracy: 0.9726 - val_auc_2: 0.9831
# Epoch 435/500
# 72/72 [==============================] - 1s 8ms/step - loss: 0.0631 - accuracy: 0.9710 - auc_2: 0.9952 - val_loss: 0.0980 - val_accuracy: 0.9726 - val_auc_2: 0.9752
# Epoch 436/500
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0669 - accuracy: 0.9714 - auc_2: 0.9934 - val_loss: 0.0947 - val_accuracy: 0.9776 - val_auc_2: 0.9820
# Epoch 437/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0797 - accuracy: 0.9662 - auc_2: 0.9907 - val_loss: 0.0855 - val_accuracy: 0.9726 - val_auc_2: 0.9900
# Epoch 438/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9604 - auc_2: 0.9914 - val_loss: 0.0858 - val_accuracy: 0.9751 - val_auc_2: 0.9891
# Epoch 439/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9723 - auc_2: 0.9955 - val_loss: 0.0901 - val_accuracy: 0.9751 - val_auc_2: 0.9892
# Epoch 440/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0707 - accuracy: 0.9670 - auc_2: 0.9928 - val_loss: 0.0864 - val_accuracy: 0.9801 - val_auc_2: 0.9893
# Epoch 441/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0770 - accuracy: 0.9653 - auc_2: 0.9932 - val_loss: 0.0871 - val_accuracy: 0.9776 - val_auc_2: 0.9903
# Epoch 442/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 0.9727 - auc_2: 0.9949 - val_loss: 0.0907 - val_accuracy: 0.9677 - val_auc_2: 0.9830
# Epoch 443/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9675 - auc_2: 0.9932 - val_loss: 0.0900 - val_accuracy: 0.9701 - val_auc_2: 0.9830
# Epoch 444/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0721 - accuracy: 0.9657 - auc_2: 0.9938 - val_loss: 0.0928 - val_accuracy: 0.9776 - val_auc_2: 0.9835
# Epoch 445/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9741 - auc_2: 0.9954 - val_loss: 0.0928 - val_accuracy: 0.9726 - val_auc_2: 0.9819
# Epoch 446/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0725 - accuracy: 0.9701 - auc_2: 0.9937 - val_loss: 0.0916 - val_accuracy: 0.9726 - val_auc_2: 0.9835
# Epoch 447/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9675 - auc_2: 0.9942 - val_loss: 0.0933 - val_accuracy: 0.9751 - val_auc_2: 0.9834
# Epoch 448/500
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0669 - accuracy: 0.9701 - auc_2: 0.9946 - val_loss: 0.0907 - val_accuracy: 0.9701 - val_auc_2: 0.9822
# Epoch 449/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0679 - accuracy: 0.9705 - auc_2: 0.9934 - val_loss: 0.0895 - val_accuracy: 0.9726 - val_auc_2: 0.9893
# Epoch 450/500
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0709 - accuracy: 0.9684 - auc_2: 0.9926 - val_loss: 0.0947 - val_accuracy: 0.9726 - val_auc_2: 0.9755
# Epoch 451/500
# 72/72 [==============================] - 0s 6ms/step - loss: 0.0761 - accuracy: 0.9692 - auc_2: 0.9934 - val_loss: 0.0888 - val_accuracy: 0.9776 - val_auc_2: 0.9889
# Epoch 452/500
# 72/72 [==============================] - 0s 7ms/step - loss: 0.0776 - accuracy: 0.9626 - auc_2: 0.9929 - val_loss: 0.0870 - val_accuracy: 0.9726 - val_auc_2: 0.9900
# Epoch 453/500
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0794 - accuracy: 0.9675 - auc_2: 0.9892 - val_loss: 0.0928 - val_accuracy: 0.9726 - val_auc_2: 0.9895
# Epoch 454/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0697 - accuracy: 0.9675 - auc_2: 0.9941 - val_loss: 0.0940 - val_accuracy: 0.9776 - val_auc_2: 0.9893
# Epoch 455/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9736 - auc_2: 0.9953 - val_loss: 0.0947 - val_accuracy: 0.9751 - val_auc_2: 0.9821
# Epoch 456/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0750 - accuracy: 0.9692 - auc_2: 0.9922 - val_loss: 0.1028 - val_accuracy: 0.9726 - val_auc_2: 0.9855
# Epoch 457/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.9684 - auc_2: 0.9899 - val_loss: 0.1015 - val_accuracy: 0.9701 - val_auc_2: 0.9795
# Epoch 458/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9657 - auc_2: 0.9918 - val_loss: 0.0981 - val_accuracy: 0.9701 - val_auc_2: 0.9881
# Epoch 459/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0660 - accuracy: 0.9723 - auc_2: 0.9926 - val_loss: 0.0995 - val_accuracy: 0.9701 - val_auc_2: 0.9872
# Epoch 460/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0655 - accuracy: 0.9723 - auc_2: 0.9948 - val_loss: 0.0935 - val_accuracy: 0.9776 - val_auc_2: 0.9884
# Epoch 461/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0668 - accuracy: 0.9714 - auc_2: 0.9947 - val_loss: 0.0959 - val_accuracy: 0.9776 - val_auc_2: 0.9823
# Epoch 462/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0685 - accuracy: 0.9732 - auc_2: 0.9938 - val_loss: 0.0842 - val_accuracy: 0.9751 - val_auc_2: 0.9893
# Epoch 463/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9662 - auc_2: 0.9935 - val_loss: 0.0951 - val_accuracy: 0.9751 - val_auc_2: 0.9873
# Epoch 464/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 0.9723 - auc_2: 0.9954 - val_loss: 0.0957 - val_accuracy: 0.9776 - val_auc_2: 0.9766
# Epoch 465/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0608 - accuracy: 0.9727 - auc_2: 0.9958 - val_loss: 0.0985 - val_accuracy: 0.9701 - val_auc_2: 0.9826
# Epoch 466/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9741 - auc_2: 0.9944 - val_loss: 0.1149 - val_accuracy: 0.9726 - val_auc_2: 0.9748
# Epoch 467/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0653 - accuracy: 0.9745 - auc_2: 0.9939 - val_loss: 0.0874 - val_accuracy: 0.9726 - val_auc_2: 0.9771
# Epoch 468/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0756 - accuracy: 0.9675 - auc_2: 0.9921 - val_loss: 0.0900 - val_accuracy: 0.9801 - val_auc_2: 0.9826
# Epoch 469/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 0.9719 - auc_2: 0.9951 - val_loss: 0.0939 - val_accuracy: 0.9776 - val_auc_2: 0.9758
# Epoch 470/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0629 - accuracy: 0.9714 - auc_2: 0.9956 - val_loss: 0.0954 - val_accuracy: 0.9751 - val_auc_2: 0.9761
# Epoch 471/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9701 - auc_2: 0.9937 - val_loss: 0.0978 - val_accuracy: 0.9701 - val_auc_2: 0.9754
# Epoch 472/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0614 - accuracy: 0.9741 - auc_2: 0.9942 - val_loss: 0.1148 - val_accuracy: 0.9652 - val_auc_2: 0.9755
# Epoch 473/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9587 - auc_2: 0.9902 - val_loss: 0.0979 - val_accuracy: 0.9751 - val_auc_2: 0.9751
# Epoch 474/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 0.9670 - auc_2: 0.9945 - val_loss: 0.0930 - val_accuracy: 0.9726 - val_auc_2: 0.9881
# Epoch 475/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 0.9679 - auc_2: 0.9933 - val_loss: 0.0991 - val_accuracy: 0.9701 - val_auc_2: 0.9750
# Epoch 476/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0580 - accuracy: 0.9732 - auc_2: 0.9949 - val_loss: 0.0947 - val_accuracy: 0.9652 - val_auc_2: 0.9828
# Epoch 477/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0717 - accuracy: 0.9688 - auc_2: 0.9927 - val_loss: 0.0906 - val_accuracy: 0.9751 - val_auc_2: 0.9840
# Epoch 478/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9688 - auc_2: 0.9944 - val_loss: 0.0909 - val_accuracy: 0.9751 - val_auc_2: 0.9767
# Epoch 479/500
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0578 - accuracy: 0.9710 - auc_2: 0.9960 - val_loss: 0.0998 - val_accuracy: 0.9677 - val_auc_2: 0.9760
# Epoch 480/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0648 - accuracy: 0.9697 - auc_2: 0.9926 - val_loss: 0.0987 - val_accuracy: 0.9701 - val_auc_2: 0.9825
# Epoch 481/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0647 - accuracy: 0.9705 - auc_2: 0.9927 - val_loss: 0.0984 - val_accuracy: 0.9726 - val_auc_2: 0.9826
# Epoch 482/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9723 - auc_2: 0.9951 - val_loss: 0.0994 - val_accuracy: 0.9776 - val_auc_2: 0.9771
# Epoch 483/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0657 - accuracy: 0.9688 - auc_2: 0.9948 - val_loss: 0.0965 - val_accuracy: 0.9726 - val_auc_2: 0.9760
# Epoch 484/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 0.9723 - auc_2: 0.9951 - val_loss: 0.0867 - val_accuracy: 0.9751 - val_auc_2: 0.9832
# Epoch 485/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9692 - auc_2: 0.9917 - val_loss: 0.0910 - val_accuracy: 0.9726 - val_auc_2: 0.9824
# Epoch 486/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0673 - accuracy: 0.9697 - auc_2: 0.9948 - val_loss: 0.0874 - val_accuracy: 0.9751 - val_auc_2: 0.9894
# Epoch 487/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0646 - accuracy: 0.9701 - auc_2: 0.9950 - val_loss: 0.0913 - val_accuracy: 0.9751 - val_auc_2: 0.9838
# Epoch 488/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0677 - accuracy: 0.9644 - auc_2: 0.9931 - val_loss: 0.0969 - val_accuracy: 0.9726 - val_auc_2: 0.9824
# Epoch 489/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9741 - auc_2: 0.9948 - val_loss: 0.0941 - val_accuracy: 0.9801 - val_auc_2: 0.9762
# Epoch 490/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9705 - auc_2: 0.9935 - val_loss: 0.1011 - val_accuracy: 0.9701 - val_auc_2: 0.9742
# Epoch 491/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9688 - auc_2: 0.9925 - val_loss: 0.0962 - val_accuracy: 0.9701 - val_auc_2: 0.9753
# Epoch 492/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9688 - auc_2: 0.9931 - val_loss: 0.0954 - val_accuracy: 0.9701 - val_auc_2: 0.9875
# Epoch 493/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0711 - accuracy: 0.9688 - auc_2: 0.9938 - val_loss: 0.0998 - val_accuracy: 0.9701 - val_auc_2: 0.9808
# Epoch 494/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0596 - accuracy: 0.9714 - auc_2: 0.9959 - val_loss: 0.0908 - val_accuracy: 0.9751 - val_auc_2: 0.9823
# Epoch 495/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9710 - auc_2: 0.9935 - val_loss: 0.0918 - val_accuracy: 0.9701 - val_auc_2: 0.9828
# Epoch 496/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.9692 - auc_2: 0.9950 - val_loss: 0.0911 - val_accuracy: 0.9726 - val_auc_2: 0.9818
# Epoch 497/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9727 - auc_2: 0.9948 - val_loss: 0.0971 - val_accuracy: 0.9701 - val_auc_2: 0.9814
# Epoch 498/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9710 - auc_2: 0.9953 - val_loss: 0.0936 - val_accuracy: 0.9677 - val_auc_2: 0.9817
# Epoch 499/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 0.9732 - auc_2: 0.9957 - val_loss: 0.1005 - val_accuracy: 0.9701 - val_auc_2: 0.9756
# Epoch 500/500
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9653 - auc_2: 0.9941 - val_loss: 0.0875 - val_accuracy: 0.9751 - val_auc_2: 0.9834

# %%
# Plot the loss across epochs
losses = pd.DataFrame(history.history)
losses[['loss','val_loss']].plot()

# %%
# Save model
model.save('iran_churn_model.h5')

# %% [markdown]
# ### Evaluate the model's performance
#
# #### This fitted model can actually serve as two different models: one cost insensitive and the other cost sensitive. Below I will compare the generalization/test set performances of these two models.

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
def classification_report_confusion_matrix(y_pred, labels):
    """
    Function takes predictions and labels as input, 
    prints out a classification report,
    and returns a confusion matrix object.
    """
    print('\n')
    print(classification_report(labels, y_pred))
    return confusion_matrix(labels, y_pred)

# %%
def plot_confusion_matrices(cm_1, cm_2, labels=['Insensitive Model', 'Sensitive Model']):
    """
    Function takes two confusion matrices
    and their respective labels
    and plots them side by side.
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

    sns.heatmap(cm_1, annot=True, ax = ax1, fmt='g', cmap='Blues');

    ax1.set_xlabel('Predicted labels')
    ax1.set_ylabel('True labels') 
    ax1.set_title(labels[0])
    ax1.xaxis.set_ticklabels(['No Churn (0)', 'Churn (1)'])   
    ax1.yaxis.set_ticklabels(['No Churn (0)', 'Churn (1)'])


    sns.heatmap(cm_2, annot=True, ax = ax2, fmt='g', cmap='Greens');

    ax2.set_xlabel('Predicted labels')
    ax2.set_ylabel('True labels') 
    ax2.set_title(labels[1])
    ax2.xaxis.set_ticklabels(['No Churn (0)', 'Churn (1)'])   
    ax2.yaxis.set_ticklabels(['No Churn (0)', 'Churn (1)'])
    
    plt.tight_layout()

# %% [markdown]
# ### Test set performance
# At the end of the day, we care about how this model generalizes to new, unseen data. Therefore, to keep the notebook clean I will only review the results on the test set, but these same metrics and plots could easily be calculated for the training and validation sets as well.

# %%
# Check the model's AUC score. This is the cost insensitive model.
print("AUC Score: ", model.evaluate(X_test_scaled, y_test)[2])
# Out:
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9662 - auc_2: 0.9876
# AUC Score:  0.9876210689544678

# %%
# Compare the classification reports
print('COST INSENSITIVE MODEL')
y_pred_insensitive = model.predict_classes(X_test_scaled)
insensitive_cm = classification_report_confusion_matrix(y_pred_insensitive, y_test)
print('\n')
print("COST SENSITIVE MODEL")
y_pred_sensitive = expected_value_prediction(model, X_test_scaled, test_misclassification_cost_df)
sensitive_cm = classification_report_confusion_matrix(y_pred_sensitive, y_test)
# Out:
# COST INSENSITIVE MODEL
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       399
#            1       0.88      0.91      0.89        74
#
#     accuracy                           0.97       473
#    macro avg       0.93      0.94      0.94       473
# weighted avg       0.97      0.97      0.97       473
#
#
#
# COST SENSITIVE MODEL
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       399
#            1       0.94      0.64      0.76        74
#
#     accuracy                           0.94       473
#    macro avg       0.94      0.81      0.86       473
# weighted avg       0.94      0.94      0.93       473

# %% [markdown]
# While both models achieve fairly high accuracy, what immediately jumps out to me is how low the cost sensitive model's class 1 recall score is compared to that of the cost insensitive model. This means that the cost sensitive model detects a lower percentage of positive class instances (Churn instances) in the dataset than the cost insensitive model does. Furthermore, this indicates that the cost sensitive model was more worried about making false positive errors than false negative errors.

# %%
# Show side by side comparison of the confusion matrices
plot_confusion_matrices(insensitive_cm, sensitive_cm)

# %% [markdown]
# The confusion matrix above illustrates the cost sensitive model's preference for predicting the negative class, even if it leads to a greater number of misclassifications overall. In fact, the cost sensitive model misclassified more instances overall in what seems to be an effort to avoid making false positive errors in favor of false negatives.

# %% [markdown]
# #### Compare the total cost in dollars of each model's predictions

# %%
print("Insensitive Model Total cost: $", calculate_cost(y_test.tolist(), y_pred_insensitive, 
                                                        test_misclassification_cost_df))
print("Sensitive Model Total cost: $", calculate_cost(y_test.tolist(), y_pred_sensitive, 
                                                      test_misclassification_cost_df))
# Out:
# Insensitive Model Total cost: $ 1820.935
# Sensitive Model Total cost: $ 1159.668

# %% [markdown]
# These results above explain why the cost sensitive model performs worse at the classification task: its objective is to minimize cost not misclassification error.
#
# Although the cost sensitive model makes more misclassification errors overall, the model makes predictions that result in a lower overall cost. This highlights how the cost sensitive model is willing to misclassify many instances as long as it leads to predictions with a lower overall dollar cost in the end.

# %% [markdown]
# #### For the cost sensitive model, print the cost of the baseline strategy of random guessing and the cost savings

# %%
evaluate_cost_savings(model, test_misclassification_cost_df, X_test_scaled, y_test)
print('')
# Out:
# Random Guess Baseline Cost: $25802.35
# Model Cost: $1159.67
# Cost Savings: $24642.69

# %%
print('Proportion of baseline cost saved, Test set: ', 24642.69 / 25802.35)
# Out:
# Proportion of baseline cost saved, Test set:  0.9550560317180412

# %% [markdown]
# The true measure of a cost sensitive model is not accuracy or AUC score, but rather how much money it saves the business compared to an alternative strategy. If we assume the baseline alternative strategy is randomly guessing which customers will churn, then this cost sensitive model reduces costs by about 96%.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# I have built a neural network model that can predict whether a customer will churn with a high degree of accuracy. More importantly though, I have build a predictive model that optimizes a business's costs.
#
# Although it minimizes costs, the cost sensitive model I built does misclassify more customers than the cost insensitive model. This is because a cost insensitive model assumes every misclassification is equally costly, so it's goal is to reduce misclassification as much as possible. On the other hand, a cost sensitive model can account for the fact that not all misclassifications are created equal by making cost-weighted predictions. The model I built developed a clear preference for making false negative errors rather than false positive errors. In other words, the model would rather miss flagging a customer that will actually churn than flag a customer that will not churn.
#
# NOTE: The creators/maintainers of this dataset don't make it clear where the false positive and false negative cost values come from. Therefore, this analysis of the relative costs of false negatives and false positives assumes that the provided cost values are correct *without any further context*. Whether or not it makes sense for false postive churn errors to be more costly on average than false negative errors depends on context I cannot explain. Nevertheless, the procedure I performed will produce the optimal model given any set of false positive and false negative costs.
#
# Finally, there are a few limitations worth mentioning.
#
# First, this model is not very explainable. The deep neural network model performs very well, but it is not clear what features it uses to determine if a customer will churn. If the purpose of this model is purely prediction and optimization, then this lack of interpretability is not very important. However, if the company wanted to use this model as a way to understand which variables were important for determining customer churn, then a more interpretable model, such as Gradient Boosting trees should be used.
#
# Second, for my custom metric, I used "Cost Savings", which was defined as the dollar difference between a baseline cost and the cost sensitive model's cost. For the baseline cost, I assumed the company would randomly predict which customers would churn and calculated the cost based on these predictions. It's unlikely that a company would actually guess churn at random like this, but without any further context on the company's existing strategy, I chose this simple strategy as my baseline.
#
# Overall this was a very enjoyable project. Although telecoms churn problems are not particularly interesting, the dataset's inclusion of misclassification costs was a novel challenge that forced me to develop clever strategies for building and optimizing a cost sensitive neural net model.
